# %% [markdown]
# <a href="https://colab.research.google.com/github/david-1192/Senales_y_Sistemas_2025/blob/main/Cuaderno3_Operaciones_de_se%C3%B1ales_continuas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operaciones básicas sobre señales
#
# Las operaciones como la superposición, el cambio temporal y el escalamiento, se utilizan para construir señales con una estructura más compleja.
#
# Se introduce un conjunto de operaciones elementales que se utilizan frecuentemente en el procesamiento de señales.

# %% [markdown]
# ### Superposición
#
# La superposición $x(t)$ de dos señales $x_1(t)$ and $x_2(t)$ está dada por:
#
# \begin{equation}
# x(t) = A \cdot x_1(t) + B \cdot x_2(t)
# \end{equation}
#
# con los pesos complejos $A, B \in \mathbb{C}$.

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra la superposición de dos señales armónicas $x(t) = A \cdot \cos(\omega_1 t) + B \cdot \cos(\omega_2 t)$ con pesos $A$, $B$ y frecuencia angular $\omega_1$ y $\omega_2$.

# %%
# %matplotlib inline
import sympy as sym

t = sym.symbols('t', real=True)#se declara la variable simbólica t

#parámetros de las funciones cos
#El punto indica escibir de forma abreviada 0.3 o 0.5
A = .3
om1 = 3
B = .5
om2 = 5

#operación superposición en sympy
x = A*sym.cos(om1*t) + B*sym.cos(om2*t)
#se grafica la señal resultante
sym.plot(x, (t,-5,5), ylim=[-1.2, 1.2], ylabel=r'$x(t)$');

# %% [markdown]
# ### Desplazamiento temporal
#
# El desplazamiento temporal de una señal $s(t)$ en un instante de tiempo $\tau$ es una operación frecuentemente aplicada en el procesamiento de señales. Por ejemplo, para modelar la propagación de señales desde un actuador a un sensor.
#
# El desplazamiento de la señal $x(t)$ está definido como:
#
# \begin{equation}
# x(t) = s(t-\tau)
# \end{equation}
#
# con $\tau \in \mathbb{R}$. La señal $s(t)$ es:
#
# * desplazada hacia la derecha (*retrasada*) para $\tau > 0$
# * desplazada hacia la izquierda para $\tau < 0$

# %% [markdown]
# **Ejemplo**
#
# Para ilustrar el cambio temporal de señales, la construcción de una señal escalera por una superposición de desplazamiento se define como:
#
# \begin{equation}
# x(t) = \text{rect}\left(t - \frac{1}{2} \right) + \frac{2}{3} \cdot \text{rect}\left(t-\frac{3}{2} \right) + \frac{1}{3} \cdot \text{rect} \left(t-\frac{5}{2} \right)
# \end{equation}

# %%
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)
sym.plot(rect, xlim=[-2,2], ylabel = r'rect(t)')
#los rect desplazados se acoplan con escalamientos diferentes
x = rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2)
sym.plot(x, (t, -1, 5), ylim=[-0.2, 1.2], ylabel='$x(t)$');

# %% [markdown]
# **Ejercicio**
#
# * Agregar otro escalón al principio de la señal escalera modificando el ejemplo anterior.

# %% [markdown]
# **Ejercicio: Agregar un escalón al principio**
#
# Para abordar este ejercicio, el objetivo es modificar la expresión de la señal escalera original para incluir un escalón adicional que comience antes que los demás.
#
# La señal escalera original se construye mediante la superposición de tres funciones rectangulares (`rect`) desplazadas temporalmente y escaladas. Para agregar un escalón al principio, necesitamos incluir otra función `rect` que esté desplazada hacia la izquierda en el tiempo.
#
# La nueva expresión para la señal escalera modificada será la suma de este nuevo escalón inicial y los escalones originales con sus respectivos pesos y desplazamientos. La visualización gráfica nos permitirá confirmar que se ha agregado el escalón esperado al principio de la señal.

# %%
# Escalon agregado al principio de la señal escalera modifaca del ejemplo anterior

rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)
sym.plot(rect, xlim=[-2,2], ylabel = r'rect(t)')
#los rect desplazados se acoplan con escalamientos diferentes
x = rect.subs(t, t+1/2) + rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2) # se agrega el escalón al principio
sym.plot(x, (t, -2, 5), ylim=[-0.2, 1.2], ylabel='$x(t)$');

# %% [markdown]
# ### Escalamiento temporal
#
# El escalamiento temporal de una señal $s(t)$ está definido como:
#
# \begin{equation}
# x(t) = s(a \cdot t)
# \end{equation}
#
# con $a \in \mathbb{R}$. La señal $s(t)$ es
#
# * estirada para $0 < a < 1$
# * comprimida $a > 1$
# * invertida y escalada para $a < 0$
#
# Una aplicación de escalado temporal en el procesamiento de la señal es la escala de las señales estándar y el modelado del [efecto Doppler](https://en.wikipedia.org/wiki/Doppler_effect).

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra el escalamiento de una señal escalera $y(t) = x(a \cdot t)$.

# %%
a = sym.symbols('a', real=True)
y = x.subs(t, a*t)

px = sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False, line_color='gray')
py = sym.plot(y.subs(a,1/2), (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False)
px.extend(py)#se extiende los gráficos sobre una misma figura
px.show()

# %% [markdown]
# **Ejercicio**
#
# * Modifique el ejemplo anterior para que la señal se comprima.
# * Modifique el ejemplo anterior para que la señal se escale y se invierta. ¿Qué factor de escala `a`da como resultado un       estiramiento/compresión en este contexto?

# %% [markdown]
# **Discusión del Ejercicio de Escalamiento Temporal**
#
# Modificando el ejemplo para ilustrar la compresión y la inversión/escalamiento temporal.
#
# *   **Compresión:** Al establecer el factor de escala `a > 1` (en nuestro caso `a=2`), observamos que la señal se "encoge" horizontalmente, concentrando sus cambios en un menor intervalo de tiempo.
#
# *   **Inversión y Escalamiento:** Con `a < 0` (ej. `a=-2`), la señal no solo se escala (comprime en este caso ya que el valor absoluto de `a` es > 1), sino que también se invierte respecto al eje vertical.
#
# En general, un factor `|a| > 1` provoca compresión y `0 < |a| < 1` provoca estiramiento. El signo de `a` determina si hay inversión (`a < 0`) o no (`a > 0`).

# %%
# Señal comprimida utilizando el ejemplo anterior

# Definir la señal original (x)
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)
x = rect.subs(t, t+1/2) + rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2)

# Escalar la señal con a = 2 para comprimirla
a = 2
y = x.subs(t, a*t)

# Graficar las señales original y escalada
px = sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False, line_color='gray') #Señal Original
py = sym.plot(y, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False) #Señal comprimida
px.extend(py)
px.show()

# %%
# Señal escalable e invertida.

# Definir la señal original (x)
rect = sym.Heaviside(t + 0.5) - sym.Heaviside(t - 0.5)
x = rect.subs(t, t+1/2) + rect.subs(t, t-1/2) + 2/3*rect.subs(t, t-3/2) + 1/3*rect.subs(t, t-5/2)

# Escalar e invertir la señal con a = -2
a = -2
y = x.subs(t, a*t)

# Graficar las señales original y escalada
px = sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False, line_color='gray') #Señal Original
py = sym.plot(y, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False) #Señal Invertida
px.extend(py)
px.show()

# %% [markdown]
# ### Desplazamiento Temporal

# %% [markdown]
# El desplazamiento temporal de una señal $s(t)$ está definido como
#
# \begin{equation}
# x(t) = s(\tau - t)
# \end{equation}
#
# para $\tau \in \mathbb{R}$. Como $s(\tau - t) = s(- (t - \tau))$ la operación espejo también se puede representar como una inversión temporal de la señal $s(t)$ seguida por un desplazamiento de $\tau$ de la señal invertida. Para $\tau = 0$ este resultado es solo una inversión temporal de la señal.
#
# La operación de cambio temporal puede interpretarse geométricamente como un reflejo de la señal $s(t)$ en el eje vertical $t=\frac{\tau}{2}$.

# %% [markdown]
# **Ejemplo**
#
# El siguiente ejemplo ilustra el cambio temporal $y(t) = x(\tau - t)$ de la señal escalera $x(t)$ anteriormente introducida.

# %%
tau =-1
y = x.subs(t, tau - t)

px=sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', line_color='gray', show=False)
py=sym.plot(y, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False)
px.extend(py)
px.show()

# %% [markdown]
# **Ejercicio**
#
# * Para que valor de $\tau$, ¿la señal comienza en $t=0$?
# * Realice un cambio temporal dividiendo en dos operaciones consecutivas: (i) Inversión temporal y (ii) Desplazamiento temporal.

# %% [markdown]
# **Discusión: Para que valor de  τ , ¿la señal comienza en  t=0 ?**
#
# Para que la señal $x(\tau - t)$ comience en $t=0$, considerando que la señal escalera modificada con el escalón adicional comienza en $t=-1$, el valor de $\tau$ debe ser $-1$. Esto se debe a que la operación $x(\tau - t)$ refleja la señal original alrededor del eje $t = \tau/2$$t = \tau/2$. Para que el punto inicial de la señal original en $t=-1$ aparezca en $t=0$ después de la reflexión, el eje de reflexión $\tau/2$ debe estar a mitad de camino entre $-1$ y $0$, es decir, en $t=-0.5$ Resolviendo $\tau/2 = -0.5$, obtenemos $\tau = -1$.

# %%
#Cambio temporal dividiendo en dos operaciones consecutivas

#Paso 1: Inversion Temporal
x_invertida = x.subs(t, -t)

#Paso 2: Desplazamiento temporal
x_desplazada = x_invertida.subs(t, t - tau)

# Paso 2: Desplazamiento temporal con respecto a la señal original
#x_desplazada = x.subs(t, t - tau)

#Paso 3: Graficar las señales
px = sym.plot(x, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', line_color='gray', show=False)
py = sym.plot(x_invertida, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$',line_color='green', show=False)
pz = sym.plot(x_desplazada, (t, -7, 7), ylim=[-0.2, 1.2], ylabel=r'$y(t)$', show=False)

px.extend(py)
px.extend(pz)
px.show()

# %% [markdown]
# **Copyright**
#
# The notebook is provided as [Open Educational Resource](https://de.wikipedia.org/wiki/Open_Educational_Resources). Feel free to use the notebook for your own educational purposes. The text is licensed under [Creative Commons Attribution 4.0](https://creativecommons.org/licenses/by/4.0/), the code of the IPython examples under the [MIT license](https://opensource.org/licenses/MIT). Please attribute the work as follows: *Signals and Systems* by Sascha Spors.
